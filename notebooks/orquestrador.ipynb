# %%
import subprocess
import time

print(f"\n========== INICIANDO PIPELINE ==========")
start_time = time.time()

print("=== Iniciando Bronze ===")
# O comando %run executa o notebook como se fosse parte deste aqui
# %run "./ingestao_bronze.ipynb"
print("✅ Bronze finalizado com sucesso!")

print("=== Iniciando Silver ===")
# %run "./processamento_silver.ipynb"
print("✅ Silver finalizado com sucesso!")

print("=== Iniciando Gold ===")
# %run "./carga_gold.ipynb"
print("✅ Gold finalizado com sucesso!")
            
print("\n========== PIPELINE FINALIZADO ==========")
# Out:
# ========== INICIANDO PIPELINE ==========
# === Iniciando Bronze ===
# Extraindo dados de cada api:
# Dados coletados com sucesso! Total: 185
# Dados coletados com sucesso! Total: 185
# Dados coletados com sucesso! Total: 185
# Dados coletados com sucesso! Total: 185
# Dados coletados com sucesso! Total: 185
# Dados coletados com sucesso! Total: 185
# Salvo em Bronze: hdfs://namenode:9000/datalake/bronze/suicidio_b
# Salvo em Bronze: hdfs://namenode:9000/datalake/bronze/suicidio_f
# Salvo em Bronze: hdfs://namenode:9000/datalake/bronze/suicidio_m
# Salvo em Bronze: hdfs://namenode:9000/datalake/bronze/depressao_b
# Salvo em Bronze: hdfs://namenode:9000/datalake/bronze/depressao_f
# Salvo em Bronze: hdfs://namenode:9000/datalake/bronze/depressao_m
# ✅ Bronze finalizado com sucesso!
# === Iniciando Silver ===
# Salvando dados tratados no HDFS (Silver)...
# Dados Silver salvos com sucesso!
# ✅ Silver finalizado com sucesso!
# === Iniciando Gold ===
# ...
